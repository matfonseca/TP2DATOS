# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier

# %matplotlib inline

# %%
postulations_encoded = pd.read_csv('../MapDataAnalysis/MappedData4M.csv')

# %%
postulations_encoded.head()
# Out:
#    Unnamed: 0  descripcion     idaviso idpostulante      nombre_area  \
# 0           0            0  1111662226      EzpVOLz     Farmacéutica
# 1           1            0  1111413600      kPjordV    Telemarketing
# 2           2            1  1112401116      pzNk9Rr  Soporte Técnico
# 3           3            0  1112319004      vV3BMz1           Ventas
# 4           4            0  1112094756       a4GRrN      Call Center
#
#    nombre_sort  se_postulo                                             titulo  \
# 0          3.0           1                    Cajeros/as- Atencion al cliente
# 1          3.0           1  Operador telefónico /  Retención y Fidelizació...
# 2          1.0           1                 Técnico en Reparación de Celulares
# 3          1.0           1                       Asesores Comerciales NEUQUEN
# 4          3.0           1        Representante de Atencion al Cliente/ Banco
#
#    estadoEncoded  tipoDeTrabajoEncoded  nivelLaboralEncoded  sexoEncoded  \
# 0              0                     0                    2            1
# 1              0                     1                    2            1
# 2              1                     0                    1            1
# 3              1                     0                    1            1
# 4              2                     1                    0            1
#
#    edadEncoded  zonaEncoded
# 0          3.0            0
# 1          0.0            1
# 2          3.0            0
# 3          4.0            1
# 4          3.0            0

# %%
postulations_encoded= postulations_encoded.drop(['idaviso','idpostulante','Unnamed: 0', 'titulo','descripcion'],axis=1)

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
for column in postulations_encoded.columns:
    if postulations_encoded[column].dtype == type(object):
        postulations_encoded[column] = le.fit_transform(postulations_encoded[column].astype(str))

postulations_encoded.sample(5)
# Out:
#          nombre_area  nombre_sort  se_postulo  estadoEncoded  \
# 420184            77          3.0           1              1
# 3043623          157          1.0           0              1
# 1045841          172          3.0           1              1
# 286299           183          1.0           1              1
# 2867045          173          3.0           0              1
#
#          tipoDeTrabajoEncoded  nivelLaboralEncoded  sexoEncoded  edadEncoded  \
# 420184                      0                    1            1          3.0
# 3043623                     0                    0            1          1.0
# 1045841                     1                    1            2          2.0
# 286299                      1                    2            0          4.0
# 2867045                     1                    0            1          4.0
#
#          zonaEncoded
# 420184             0
# 3043623            0
# 1045841            0
# 286299             0
# 2867045            0

# %%
#Normalizamos los valores
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() 
scaled_values = scaler.fit_transform(postulations_encoded) 
postulations_encoded.loc[:,:] = scaled_values

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(postulations_encoded.drop(['se_postulo'], axis=1).values, postulations_encoded['se_postulo'], test_size=0.30, random_state=75)

# %%
#Crear Arbol de decision con profundidad = DEPENDE DE QUE DE LA CELDA ANTERIOR
from sklearn import tree
decision_tree = tree.DecisionTreeClassifier()

# %%
decision_tree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
decision_tree.predict(X_test)
# Out:
# array([0., 0., 1., ..., 1., 1., 1.])

# %%
#Pruebo el score para ver si realiza overfitting
decision_tree.score(X_test,y_test)
# Out:
# 0.7062964172381168

# %%
test = pd.read_csv('../MapDataAnalysis/MappedTest.csv')

# %%
test.head()
# Out:
#    id  idaviso idpostulante  nombre_sort  \
# 0   0   739260       6M9ZQR          6.0
# 1   1   739260       6v1xdL          2.0
# 2   2   739260       ezRKm9          3.0
# 3   3   758580       1Q35ej          4.0
# 4   4   758580       EAN4J6          3.0
#
#                                         titulo  descripcion  \
# 0                          Asistente Comercial            1
# 1                          Asistente Comercial            1
# 2                          Asistente Comercial            1
# 3  Oracle Financials Sr. Application Developer            0
# 4  Oracle Financials Sr. Application Developer            0
#
#              nombre_area  estadoEncoded  tipoDeTrabajoEncoded  \
# 0              Comercial              1                     0
# 1              Comercial              1                     0
# 2              Comercial              1                     0
# 3  Tecnologia / Sistemas              1                     0
# 4  Tecnologia / Sistemas              2                     0
#
#    nivelLaboralEncoded  sexoEncoded  edadEncoded  zonaEncoded
# 0                    3            0          4.0          1.0
# 1                    3            1          3.0          1.0
# 2                    3            0          3.0          1.0
# 3                    2            1          4.0          1.0
# 4                    2            0          3.0          1.0

# %%
test = test.drop(['idaviso','idpostulante','titulo','descripcion'],axis=1)

# %%
le = preprocessing.LabelEncoder()
for column in test.columns:
    if test[column].dtype == type(object):
        test[column] = le.fit_transform(test[column].astype(str))

# %%
#Normalizamos los valores
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler() 
scaled_values = scaler.fit_transform(test.drop(columns = ['id'])) 
test.loc[:,1:] = scaled_values

# %%
test.head()
# Out:
#    id  nombre_sort  nombre_area  estadoEncoded  tipoDeTrabajoEncoded  \
# 0   0     1.000000     0.160221            0.5                   0.0
# 1   1     0.333333     0.160221            0.5                   0.0
# 2   2     0.500000     0.160221            0.5                   0.0
# 3   3     0.666667     0.906077            0.5                   0.0
# 4   4     0.500000     0.906077            1.0                   0.0
#
#    nivelLaboralEncoded  sexoEncoded  edadEncoded  zonaEncoded
# 0                 0.75          0.0         1.00     0.333333
# 1                 0.75          0.5         0.75     0.333333
# 2                 0.75          0.0         0.75     0.333333
# 3                 0.50          0.5         1.00     0.333333
# 4                 0.50          0.0         0.75     0.333333

# %%
result = decision_tree.predict_proba(test.drop(['id'],axis = 1))

# %%
result2 = []
for elem in result:
    result2.append(elem[1])

# %%
test['sepostulo'] = result2

# %%
test = test[['id','sepostulo']]

# %%
test.head()
# Out:
#    id  sepostulo
# 0   0        0.0
# 1   1        0.0
# 2   2        0.0
# 3   3        1.0
# 4   4        0.0

# %%
test['sepostulo'].value_counts()
# Out:
# 0.000000    46248
# 1.000000    18278
# 0.500000     4297
# 0.333333     2678
# 0.025000     2372
# 0.666667     1240
# 0.250000     1071
# 0.800000     1020
# 0.909091     1020
# 0.200000      897
# 0.857143      895
# 0.142857      858
# 0.714286      765
# 0.727273      708
# 0.024390      695
# 0.687500      665
# 0.750000      636
# 0.833333      540
# 0.166667      493
# 0.466667      476
# 0.636364      475
# 0.428571      457
# 0.043478      455
# 0.400000      434
# 0.111111      382
# 0.444444      371
# 0.125000      328
# 0.684211      302
# 0.133333      283
# 0.100000      269
#             ...
# 0.345455        1
# 0.179487        1
# 0.141509        1
# 0.791667        1
# 0.650000        1
# 0.568966        1
# 0.866667        1
# 0.194805        1
# 0.453125        1
# 0.306452        1
# 0.265625        1
# 0.608696        1
# 0.340782        1
# 0.184211        1
# 0.722973        1
# 0.531250        1
# 0.476190        1
# 0.558140        1
# 0.289256        1
# 0.937500        1
# 0.198276        1
# 0.863636        1
# 0.704120        1
# 0.515625        1
# 0.733840        1
# 0.406091        1
# 0.228571        1
# 0.542857        1
# 0.050000        1
# 0.964286        1
# Name: sepostulo, Length: 355, dtype: int64

# %%
test.to_csv('../Predictions/DecisionTree4M.csv', index=False)
